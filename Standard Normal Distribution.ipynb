# %%
import pandas as pd

# %%
dataset=pd.read_csv("Preplacementdata.csv")

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# ssc_p             0
# hsc_p             0
# degree_p          0
# etest_p           0
# mba_p             0
# salary            0
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# dtype: int64

# %%
#to display the distribution plot seaborn is used if the version is old or not working install the seaborn using 
#pip install seaborn

# %%
import seaborn as sns

# %%
sns.distplot(dataset["ssc_p"])
# Out:
# C:\Users\hp\.conda\envs\aiml\lib\site-packages\ipykernel_launcher.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """Entry point for launching an IPython kernel.

# %%
#the above image represent curve is density and bars is histogram

# %%
def get_pdf_probability(dataset,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
    pyplot.axvline(startrange,color='Red')
    pyplot.axvline(endrange,color='Red')
    
    #generate a sample
    sample= dataset
    #calculate parameters
    sample_mean = sample.mean()
    sample_std = sample.std()
    print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))
    #define the distribution
    dist = norm(sample_mean,sample_std)
    
    #sample probabilities for a range of outcomes
    values = [value for value in range(startrange,endrange)]
    probabilities = [dist.pdf(value)for value in values]
    prob=sum(probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
#get_pdf_probability(dataset,startrange,endrange)

# %%
get_pdf_probability(dataset["ssc_p"],60,70)
# Out:
# Mean=67.303, Standard Deviation=10.827
# The area between range(60,70):0.3449514151280293
# C:\Users\hp\.conda\envs\aiml\lib\site-packages\ipykernel_launcher.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """
# 0.3449514151280293

# %%
#the different between 60 to 70 is std is 0.344 is 34% of data is covered and Mean is 67
#now we can check for other values

# %%
get_pdf_probability(dataset["ssc_p"],40,50)
# Out:
# Mean=67.303, Standard Deviation=10.827
# The area between range(40,50):0.04489259448345172
# C:\Users\hp\.conda\envs\aiml\lib\site-packages\ipykernel_launcher.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """
# 0.04489259448345172

# %%
#the different between 60 to 70 is std is 0.04 is 4% of data is covered and Mean is 67

# %%
get_pdf_probability(dataset["ssc_p"],40,40)
# Out:
# Mean=67.303, Standard Deviation=10.827
# The area between range(40,40):0
# C:\Users\hp\.conda\envs\aiml\lib\site-packages\ipykernel_launcher.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """
# 0

# %%
#While the same values met the difference is zero

# %% [markdown]
# # Cumulative Distribution

# %%
from statsmodels.distributions.empirical_distribution import ECDF
ecdf= ECDF(dataset['ssc_p'])
ecdf(78)
# Out:
# 0.827906976744186

# %%
#here ecdf e stands for empirical and getting error No module named 'statsmodels' we have to instal statsmodels

# %%
#!pip install statsmodels
# Out:
# ...
#      ---------------------------------------- 9.1/9.1 MB 3.5 MB/s eta 0:00:00
# ...
#      -------------------------------------- 233.9/233.9 kB 1.8 MB/s eta 0:00:00
# ...

# %%
#after installed inserting a hastag before pip and executing again the code

# %%
from statsmodels.distributions.empirical_distribution import ECDF
ecdf= ECDF(dataset['ssc_p'])
ecdf(78)
# Out:
# 0.827906976744186

# %%
#we can also change values and calculate

# %%
from statsmodels.distributions.empirical_distribution import ECDF
ecdf= ECDF(dataset['ssc_p'])
ecdf(40)
# Out:
# 0.0

# %%
from statsmodels.distributions.empirical_distribution import ECDF
ecdf= ECDF(dataset['ssc_p'])
ecdf(50)
# Out:
# 0.05581395348837209

# %%
from statsmodels.distributions.empirical_distribution import ECDF
ecdf= ECDF(dataset['ssc_p'])
ecdf(80)
# Out:
# 0.8651162790697674

# %%
#In 80 86% will be calculated

# %%
#now converting to standard normal distribution

# %%
def stdNBgraph(dataset):
    import seaborn as sns
    mean=dataset.mean()
    std=dataset.std()
    
    values=[i for i in dataset]
    z_score=[(j-mean/std) for j in values]
    sns.displot(z_score,kde=True)
    sum(z_score)/len(z_score)
    #z_score.std()

# %%
stdNBgraph(dataset["ssc_p"])

# %%
#Standard normal distribution is not working with the code.
